# %% [markdown]
# Aula 8 - Carregando um Dadaset com pandas no Colab - Disciplina de Inteligência Artificial
#
# Dataset da Kaggle: Flipkart Smartphones

# %%
# Conctando ou drive
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importando a biblioteca pandas
import pandas as pd

# %% [markdown]
# Lendo o arquivo CSV

# %%
dataset = pd.read_csv('/content/drive/My Drive/Colab Notebooks/flipkart_smartphones.csv')

# %% [markdown]
# Lendo o as 10 primeiras linhas do cabeçalho

# %%
dataset.head(10)
# Out:
#     brand             model           colour  original_price  \
# 0    VIVO      VIVO T1 44W        Starry Sky           19990
# 1   APPLE  APPLE IPHONE 11             White           48900
# 2    VIVO      VIVO T1 44W   Midnight Galaxy           20990
# 3  XIAOMI       POCO M4 5G       Power Black           15999
# 4  XIAOMI         REDMI 10   Caribbean Green           14999
# 5  XIAOMI       POCO M4 5G         Cool Blue           15999
# 6  XIAOMI         POCO C31       Shadow Gray           11999
# 7  XIAOMI       POCO M4 5G            Yellow           15999
# 8  XIAOMI         REDMI 10    Midnight Black           14999
# 9    VIVO      VIVO T1 44W   Midnight Galaxy           23990
#
#    discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0             14499      4.5         87331     6044     4.0    128.0
# 1             47199      4.6        184191    10818     NaN    128.0
# 2             15999      4.4         51365     3750     6.0    128.0
# ...

# %% [markdown]
# Lendo as ultimas 10 linhas do dataset.

# %%
dataset.tail(10)
# Out:
#       brand                          model               colour  \
# 826  XIAOMI  XIAOMI 11T PRO 5G HYPERPHONE       Celestial Magic
# 827  XIAOMI         REDMI NOTE 10 PRO MAX          Glacial Blue
# 828  XIAOMI                   POCO M2 PRO       Out of the Blue
# 829   TECNO                 TECNO SPARK 7          Spruce Green
# 830  XIAOMI                       POCO X2         Matrix Purple
# 831  REALME               REALME GT NEO 2              NEO Blue
# 832  REALME               REALME GT NEO 2             NEO Black
# 833  REALME               REALME GT NEO 2             NEO Black
# 834  REALME                REALME X50 PRO              Rust Red
# 835  XIAOMI                   POCO M2 PRO   Two Shades of Black
#
#      original_price  discounted_price  ratings  rating_count  reviews  memory  \
# 826           35899             33500      4.1           496       56     8.0
# 827           22999             20390      4.3         16833     1271     6.0
# ...

# %% [markdown]
# Descrição do Dataset

# %%
dataset.describe()
# Out:
#        original_price  discounted_price     ratings  rating_count  \
# count      836.000000        836.000000  836.000000  8.360000e+02
# mean     26112.848086      21532.468900    4.272488  4.169612e+04
# std      23781.117479      21363.273113    0.284083  9.084175e+04
# min       4899.000000       3599.000000    0.000000  0.000000e+00
# 25%      13999.000000       9999.000000    4.200000  9.227500e+02
# 50%      17999.000000      14999.000000    4.300000  5.917500e+03
# 75%      25999.000000      22992.250000    4.400000  3.995500e+04
# max     159900.000000     152999.000000    4.700000  1.171704e+06
#
#              reviews      memory     storage  display_size  battery_capacity
# count     836.000000  757.000000  820.000000    836.000000        778.000000
# mean     3144.740431    5.225892  108.458537     16.525179       4950.931877
# std      7524.617982    2.007385   69.174406      0.682189        502.058888
# ...

# %% [markdown]
# Matriz de Covariância

# %%
dataset.cov()
# Out:
#                   original_price  discounted_price      ratings  rating_count  \
# original_price      5.655415e+08      4.925983e+08  2105.465277 -9.132102e+07
# discounted_price    4.925983e+08      4.563894e+08  2027.699383 -8.770235e+07
# ratings             2.105465e+03      2.027699e+03     0.080703  4.598210e+03
# rating_count       -9.132102e+07     -8.770235e+07  4598.210154  8.252224e+09
# reviews            -8.174105e+06     -8.509819e+06   296.501593  6.513391e+08
# memory              1.620064e+04      1.450102e+04     0.032178 -3.246914e+04
# storage             1.038377e+06      9.664950e+05     3.917166 -6.642243e+05
# display_size       -2.139533e+03     -1.537111e+03     0.007146 -1.465852e+04
# battery_capacity   -1.667575e+06     -1.278700e+06    16.001290 -3.693204e+05
#
#                        reviews        memory       storage  display_size  \
# original_price   -8.174105e+06  16200.637302  1.038377e+06  -2139.532637
# ...

# %% [markdown]
# Matriz de Correlação

# %%
dataset.corr()
# Out:
#                   original_price  discounted_price   ratings  rating_count  \
# original_price          1.000000          0.969601  0.311652     -0.042272
# discounted_price        0.969601          1.000000  0.334111     -0.045192
# ratings                 0.311652          0.334111  1.000000      0.178180
# rating_count           -0.042272         -0.045192  0.178180      1.000000
# reviews                -0.045680         -0.052938  0.138707      0.952878
# memory                  0.615380          0.689529  0.058301     -0.177136
# storage                 0.641829          0.665901  0.199217     -0.104984
# display_size           -0.131881         -0.105471  0.036875     -0.236538
# battery_capacity       -0.233214         -0.220690  0.116924     -0.008148
#
#                    reviews    memory   storage  display_size  battery_capacity
# original_price   -0.045680  0.615380  0.641829     -0.131881         -0.233214
# ...

# %% [markdown]
# Distribuição dos dados em Histograma

# %%
dataset.hist()
# Out:
# array([[<AxesSubplot:title={'center':'original_price'}>,
#         <AxesSubplot:title={'center':'discounted_price'}>,
#         <AxesSubplot:title={'center':'ratings'}>],
#        [<AxesSubplot:title={'center':'rating_count'}>,
#         <AxesSubplot:title={'center':'reviews'}>,
#         <AxesSubplot:title={'center':'memory'}>],
#        [<AxesSubplot:title={'center':'storage'}>,
#         <AxesSubplot:title={'center':'display_size'}>,
#         <AxesSubplot:title={'center':'battery_capacity'}>]], dtype=object)

# %%
dataset.hist(column=['memory'], grid=False)
# Out:
# array([[<AxesSubplot:title={'center':'memory'}>]], dtype=object)

# %% [markdown]
# Vai retorna apenas as linhas que tem Smartphones APPLE

# %%
dataset['brand']=="APPLE"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 831    True
# 832    True
# 833    True
# 834    True
# 835    True
# Name: brand, Length: 836, dtype: bool

# %%
dataset[dataset['brand']=="APPLE"]
# Out:
#      brand             model               colour  original_price  \
# 0    APPLE      VIVO T1 44W            Starry Sky           19990
# 1    APPLE  APPLE IPHONE 11                 White           48900
# 2    APPLE      VIVO T1 44W       Midnight Galaxy           20990
# 3    APPLE       POCO M4 5G           Power Black           15999
# 4    APPLE         REDMI 10       Caribbean Green           14999
# ..     ...               ...                  ...             ...
# 831  APPLE  REALME GT NEO 2              NEO Blue           38999
# 832  APPLE  REALME GT NEO 2             NEO Black           38999
# 833  APPLE  REALME GT NEO 2             NEO Black           34999
# 834  APPLE   REALME X50 PRO              Rust Red           17999
# 835  APPLE      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %% [markdown]
# Criando um dataset apenas para Smartphones APPLE

# %%
apple=dataset[dataset['brand']=="APPLE"]

# %%
apple
# Out:
#      brand             model               colour  original_price  \
# 0    APPLE      VIVO T1 44W            Starry Sky           19990
# 1    APPLE  APPLE IPHONE 11                 White           48900
# 2    APPLE      VIVO T1 44W       Midnight Galaxy           20990
# 3    APPLE       POCO M4 5G           Power Black           15999
# 4    APPLE         REDMI 10       Caribbean Green           14999
# ..     ...               ...                  ...             ...
# 831  APPLE  REALME GT NEO 2              NEO Blue           38999
# 832  APPLE  REALME GT NEO 2             NEO Black           38999
# 833  APPLE  REALME GT NEO 2             NEO Black           34999
# 834  APPLE   REALME X50 PRO              Rust Red           17999
# 835  APPLE      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %%
apple.describe()
# Out:
#        original_price  discounted_price     ratings  rating_count  \
# count      836.000000        836.000000  836.000000  8.360000e+02
# mean     26112.848086      21532.468900    4.272488  4.169612e+04
# std      23781.117479      21363.273113    0.284083  9.084175e+04
# min       4899.000000       3599.000000    0.000000  0.000000e+00
# 25%      13999.000000       9999.000000    4.200000  9.227500e+02
# 50%      17999.000000      14999.000000    4.300000  5.917500e+03
# 75%      25999.000000      22992.250000    4.400000  3.995500e+04
# max     159900.000000     152999.000000    4.700000  1.171704e+06
#
#              reviews      memory     storage  display_size  battery_capacity
# count     836.000000  757.000000  820.000000    836.000000        778.000000
# mean     3144.740431    5.225892  108.458537     16.525179       4950.931877
# std      7524.617982    2.007385   69.174406      0.682189        502.058888
# ...

# %%
apple.hist(grid=False)
# Out:
# array([[<AxesSubplot:title={'center':'original_price'}>,
#         <AxesSubplot:title={'center':'discounted_price'}>,
#         <AxesSubplot:title={'center':'ratings'}>],
#        [<AxesSubplot:title={'center':'rating_count'}>,
#         <AxesSubplot:title={'center':'reviews'}>,
#         <AxesSubplot:title={'center':'memory'}>],
#        [<AxesSubplot:title={'center':'storage'}>,
#         <AxesSubplot:title={'center':'display_size'}>,
#         <AxesSubplot:title={'center':'battery_capacity'}>]], dtype=object)

# %%
apple.boxplot(column='original_price',grid=False)
# Out:
# <AxesSubplot:>

# %%
apple2 = apple[apple['original_price']<20000]

# %%
apple2.boxplot(column='original_price',grid=False)
# Out:
# <AxesSubplot:>

# %%
apple2.hist(column='original_price',grid=False)
# Out:
# array([[<AxesSubplot:title={'center':'original_price'}>]], dtype=object)
